# %%
import numpy as np
import pandas as pd
import random

from pathlib import Path
from tqdm import tqdm

import tensorflow as tf
from tensorflow.keras.metrics import AUC
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, GRU, Input, BatchNormalization, Dropout
from ncps.wirings import AutoNCP
from ncps.keras import LTC
# Out:
# 2025-04-03 15:47:25.481601: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-03 15:47:25.561522: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-03 15:47:25.658869: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743684445.745340  991200 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743684445.770527  991200 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-03 15:47:26.004950: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Configuration

# %%
NUM_EPOCHS = 200
NUM_EXPERIMENTS = 1

def create_model(train):
    model = Sequential()
    model.add(Input(shape=(train.shape[1], train.shape[2])))

    model.add(Dropout(0.2))
    model.add(GRU(10, return_sequences=True))

    model.add(Dropout(0.2))
    model.add(GRU(10, return_sequences=True))

    model.add(Dropout(0.2))
    model.add(GRU(10, return_sequences=False))
    
    model.add(Dropout(0.2))
    model.add(Dense(6, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(optimizer=Adam(learning_rate=0.003), loss='binary_crossentropy', metrics=["accuracy", AUC(name="auc")])
    return model

# %% [markdown]
# # Experiment

# %%
ID = ["ID"]
USER = ["SubjectID"]
IDS = ["SubjectID", "VideoID"]
TARGET = ["predefinedlabel"]
FEATURES = ["Delta", "Theta", "Alpha1", "Alpha2", "Beta1", "Beta2", "Gamma1", "Gamma2"]
INIT_SEED = 6412

# %%
data_dir = Path("/home/aseliverstov/projects/brain_signals/data")
data = pd.read_csv(data_dir / "EEG_data.csv")

data["ID"] = (len(np.unique(data["VideoID"])) * data["SubjectID"] + data["VideoID"]).astype("int")
data = data[ID + USER + FEATURES + TARGET]

data.head(3)
# Out:
#    ID  SubjectID     Delta     Theta    Alpha1   Alpha2    Beta1     Beta2  \
# 0   0        0.0  301963.0   90612.0   33735.0  23991.0  27946.0   45097.0
# 1   0        0.0   73787.0   28083.0    1439.0   2240.0   2746.0    3687.0
# 2   0        0.0  758353.0  383745.0  201999.0  62107.0  36293.0  130536.0
#
#     Gamma1   Gamma2  predefinedlabel
# 0  33228.0   8293.0              0.0
# 1   5293.0   2740.0              0.0
# 2  57243.0  25354.0              0.0

# %%
def reshape_dataset(data):
    features = []
    target = []
    for cur_id in np.unique(data[ID].to_numpy()):
        cur_id_data = data[data[ID].to_numpy() == cur_id]
        target.append(np.mean(cur_id_data[TARGET].to_numpy()).astype("int"))
        features.append(cur_id_data[FEATURES].to_numpy())

    features = pad_sequences(features)
    return np.array(features), np.array(target)

def pad_sequences(arrays, pad_value=0):
    max_length = max(arr.shape[0] for arr in arrays)
    padded_arrays = [
        np.pad(
            arr,
            ((0, max_length - arr.shape[0]), (0, 0)),
            mode='constant',
            constant_values=pad_value)
            for arr in arrays
        ]
    return np.stack(padded_arrays)

# %%
X, _ = reshape_dataset(data)
model = create_model(X)
model.summary()
# Out:
# 2025-04-03 15:47:29.694615: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dropout (Dropout)               │ (None, 144, 8)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ (None, 144, 10)        │           600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 144, 10)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 144, 10)        │           660 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 144, 10)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 10)             │           660 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 6)              │            66 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             7 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,993 (7.79 KB)
#  Trainable params: 1,993 (7.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# %%time

all_acc = []
all_loss = []
all_auc = []

all_val_acc = []
all_val_loss = []
all_val_auc = []

for j, seed in tqdm(enumerate(np.arange(NUM_EXPERIMENTS) + INIT_SEED)):
    np.random.seed(int(seed))
    random.seed(int(seed))
    tf.random.set_seed(int(seed))

    train_id = np.random.choice(np.unique(np.ravel(data[USER])), 7, replace=False)
    train_index = np.isin(data[USER], train_id)

    train = data.iloc[train_index]
    test = data.iloc[~train_index]

    X_train, y_train = reshape_dataset(train)
    X_test, y_test = reshape_dataset(test)

    y_train = y_train.reshape(-1, 1)
    y_test = y_test.reshape(-1, 1)

    model = create_model(X_train)

    history = model.fit(
        X_train, y_train,
        validation_data=(X_test, y_test),
        epochs=NUM_EPOCHS,
        batch_size=10,
        verbose=1,
    )

    acc = history.history['accuracy']
    loss = history.history['loss']
    auc = history.history['auc']

    val_acc = history.history['val_accuracy']
    val_loss = history.history['val_loss']
    val_auc = history.history['val_auc']

    all_acc.append(acc)
    all_loss.append(loss)
    all_auc.append(auc)

    all_val_acc.append(val_acc)
    all_val_loss.append(val_loss)
    all_val_auc.append(val_auc)

epoch_acc = np.mean(all_acc, axis=0)
epoch_loss = np.mean(all_loss, axis=0)
epoch_auc = np.mean(all_auc, axis=0)

epoch_val_acc = np.mean(all_val_acc, axis=0)
epoch_val_loss = np.mean(all_val_loss, axis=0)
epoch_val_auc = np.mean(all_val_auc, axis=0)
# Out:
# 0it [00:00, ?it/s]
# Epoch 1/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 210ms/step - accuracy: 0.4715 - auc: 0.6426 - loss: 0.6774 - val_accuracy: 0.7667 - val_auc: 0.7889 - val_loss: 0.6321
# Epoch 2/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - accuracy: 0.7030 - auc: 0.7930 - loss: 0.6361 - val_accuracy: 0.7667 - val_auc: 0.7889 - val_loss: 0.5725
# Epoch 3/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - accuracy: 0.7185 - auc: 0.7587 - loss: 0.6041 - val_accuracy: 0.7667 - val_auc: 0.7778 - val_loss: 0.5244
# Epoch 4/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - accuracy: 0.7185 - auc: 0.7926 - loss: 0.5529 - val_accuracy: 0.7667 - val_auc: 0.7778 - val_loss: 0.4869
# Epoch 5/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - accuracy: 0.7185 - auc: 0.7270 - loss: 0.5397 - val_accuracy: 0.7667 - val_auc: 0.7778 - val_loss: 0.4588
# Epoch 6/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.7277 - auc: 0.7593 - loss: 0.5149 - val_accuracy: 0.7667 - val_auc: 0.8000 - val_loss: 0.4300
# Epoch 7/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - accuracy: 0.7221 - auc: 0.8186 - loss: 0.5165 - val_accuracy: 0.8333 - val_auc: 0.8000 - val_loss: 0.4147
# Epoch 8/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - accuracy: 0.7277 - auc: 0.7898 - loss: 0.5163 - val_accuracy: 0.8333 - val_auc: 0.8111 - val_loss: 0.4072
# Epoch 9/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 186ms/step - accuracy: 0.7277 - auc: 0.8250 - loss: 0.4938 - val_accuracy: 0.8333 - val_auc: 0.8444 - val_loss: 0.3999
# Epoch 10/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 193ms/step - accuracy: 0.7108 - auc: 0.6006 - loss: 0.5630 - val_accuracy: 0.8333 - val_auc: 0.8444 - val_loss: 0.3933
# Epoch 11/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 193ms/step - accuracy: 0.7277 - auc: 0.6811 - loss: 0.5355 - val_accuracy: 0.8333 - val_auc: 0.8444 - val_loss: 0.3922
# Epoch 12/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - accuracy: 0.7277 - auc: 0.6317 - loss: 0.5404 - val_accuracy: 0.8333 - val_auc: 0.8444 - val_loss: 0.3935
# Epoch 13/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 192ms/step - accuracy: 0.7277 - auc: 0.6852 - loss: 0.5240 - val_accuracy: 0.8333 - val_auc: 0.8556 - val_loss: 0.3925
# Epoch 14/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - accuracy: 0.7277 - auc: 0.7291 - loss: 0.5113 - val_accuracy: 0.8333 - val_auc: 0.8667 - val_loss: 0.3886
# Epoch 15/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 184ms/step - accuracy: 0.7221 - auc: 0.7251 - loss: 0.5175 - val_accuracy: 0.8333 - val_auc: 0.8778 - val_loss: 0.3837
# Epoch 16/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 192ms/step - accuracy: 0.7164 - auc: 0.7773 - loss: 0.5079 - val_accuracy: 0.8333 - val_auc: 0.8889 - val_loss: 0.3828
# Epoch 17/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 180ms/step - accuracy: 0.7277 - auc: 0.7180 - loss: 0.5239 - val_accuracy: 0.8333 - val_auc: 0.8778 - val_loss: 0.3782
# Epoch 18/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - accuracy: 0.7277 - auc: 0.7397 - loss: 0.5119 - val_accuracy: 0.8333 - val_auc: 0.8667 - val_loss: 0.3756
# Epoch 19/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - accuracy: 0.7277 - auc: 0.5777 - loss: 0.5615 - val_accuracy: 0.8333 - val_auc: 0.8889 - val_loss: 0.3735
# Epoch 20/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.7277 - auc: 0.7176 - loss: 0.5210 - val_accuracy: 0.8333 - val_auc: 0.8889 - val_loss: 0.3721
# Epoch 21/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 0.7277 - auc: 0.7333 - loss: 0.5095 - val_accuracy: 0.8333 - val_auc: 0.8889 - val_loss: 0.3702
# Epoch 22/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step - accuracy: 0.7277 - auc: 0.7727 - loss: 0.5089 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.3677
# Epoch 23/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 0.7277 - auc: 0.7758 - loss: 0.4908 - val_accuracy: 0.8333 - val_auc: 0.9444 - val_loss: 0.3647
# Epoch 24/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step - accuracy: 0.7277 - auc: 0.7119 - loss: 0.5109 - val_accuracy: 0.8333 - val_auc: 0.9178 - val_loss: 0.3600
# Epoch 25/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 188ms/step - accuracy: 0.7277 - auc: 0.8411 - loss: 0.4731 - val_accuracy: 0.8333 - val_auc: 0.9200 - val_loss: 0.3561
# Epoch 26/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 163ms/step - accuracy: 0.7277 - auc: 0.6771 - loss: 0.5275 - val_accuracy: 0.8333 - val_auc: 0.9156 - val_loss: 0.3506
# Epoch 27/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step - accuracy: 0.7277 - auc: 0.8506 - loss: 0.4730 - val_accuracy: 0.8333 - val_auc: 0.9133 - val_loss: 0.3447
# Epoch 28/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 182ms/step - accuracy: 0.7277 - auc: 0.8000 - loss: 0.4909 - val_accuracy: 0.8333 - val_auc: 0.9200 - val_loss: 0.3396
# Epoch 29/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 191ms/step - accuracy: 0.7277 - auc: 0.8249 - loss: 0.4850 - val_accuracy: 0.8333 - val_auc: 0.9133 - val_loss: 0.3421
# Epoch 30/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 237ms/step - accuracy: 0.7241 - auc: 0.8131 - loss: 0.4754 - val_accuracy: 0.8333 - val_auc: 0.9133 - val_loss: 0.3345
# Epoch 31/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 232ms/step - accuracy: 0.7221 - auc: 0.8934 - loss: 0.4520 - val_accuracy: 0.8333 - val_auc: 0.9289 - val_loss: 0.3298
# Epoch 32/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 196ms/step - accuracy: 0.7277 - auc: 0.8879 - loss: 0.4490 - val_accuracy: 0.8333 - val_auc: 0.9067 - val_loss: 0.3241
# Epoch 33/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 173ms/step - accuracy: 0.7277 - auc: 0.9059 - loss: 0.4350 - val_accuracy: 0.8333 - val_auc: 0.9089 - val_loss: 0.3236
# Epoch 34/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - accuracy: 0.7277 - auc: 0.8883 - loss: 0.4406 - val_accuracy: 0.8333 - val_auc: 0.9156 - val_loss: 0.3170
# Epoch 35/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - accuracy: 0.7277 - auc: 0.8679 - loss: 0.4488 - val_accuracy: 0.8333 - val_auc: 0.9156 - val_loss: 0.3126
# Epoch 36/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 190ms/step - accuracy: 0.7277 - auc: 0.8407 - loss: 0.4651 - val_accuracy: 0.8333 - val_auc: 0.9067 - val_loss: 0.3242
# Epoch 37/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - accuracy: 0.7277 - auc: 0.8993 - loss: 0.4260 - val_accuracy: 0.8333 - val_auc: 0.9111 - val_loss: 0.3281
# Epoch 38/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - accuracy: 0.7277 - auc: 0.8849 - loss: 0.4309 - val_accuracy: 0.8333 - val_auc: 0.9133 - val_loss: 0.3143
# Epoch 39/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - accuracy: 0.7277 - auc: 0.8840 - loss: 0.4322 - val_accuracy: 0.8333 - val_auc: 0.9133 - val_loss: 0.3090
# Epoch 40/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 185ms/step - accuracy: 0.7277 - auc: 0.8896 - loss: 0.4255 - val_accuracy: 0.8333 - val_auc: 0.9067 - val_loss: 0.3129
# Epoch 41/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.7277 - auc: 0.9201 - loss: 0.4026 - val_accuracy: 0.8333 - val_auc: 0.9067 - val_loss: 0.3121
# Epoch 42/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 196ms/step - accuracy: 0.7277 - auc: 0.9226 - loss: 0.4025 - val_accuracy: 0.8333 - val_auc: 0.9067 - val_loss: 0.3105
# Epoch 43/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 185ms/step - accuracy: 0.7619 - auc: 0.8989 - loss: 0.4067 - val_accuracy: 0.8333 - val_auc: 0.9067 - val_loss: 0.3172
# Epoch 44/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - accuracy: 0.7277 - auc: 0.8819 - loss: 0.4261 - val_accuracy: 0.8333 - val_auc: 0.9067 - val_loss: 0.3055
# Epoch 45/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 186ms/step - accuracy: 0.7619 - auc: 0.8682 - loss: 0.4413 - val_accuracy: 0.8333 - val_auc: 0.9067 - val_loss: 0.3067
# Epoch 46/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.7277 - auc: 0.9399 - loss: 0.3823 - val_accuracy: 0.8333 - val_auc: 0.9067 - val_loss: 0.3092
# Epoch 47/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 183ms/step - accuracy: 0.7390 - auc: 0.8710 - loss: 0.4297 - val_accuracy: 0.8333 - val_auc: 0.9067 - val_loss: 0.3041
# Epoch 48/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 0.7277 - auc: 0.8596 - loss: 0.4427 - val_accuracy: 0.8333 - val_auc: 0.9133 - val_loss: 0.3107
# Epoch 49/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - accuracy: 0.7277 - auc: 0.8722 - loss: 0.4154 - val_accuracy: 0.8333 - val_auc: 0.9111 - val_loss: 0.3047
# Epoch 50/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - accuracy: 0.7277 - auc: 0.8926 - loss: 0.4206 - val_accuracy: 0.8333 - val_auc: 0.9289 - val_loss: 0.2971
# Epoch 51/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 196ms/step - accuracy: 0.7277 - auc: 0.8780 - loss: 0.4224 - val_accuracy: 0.8333 - val_auc: 0.9111 - val_loss: 0.3132
# Epoch 52/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 171ms/step - accuracy: 0.7619 - auc: 0.8893 - loss: 0.4171 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.3010
# Epoch 53/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - accuracy: 0.6870 - auc: 0.8925 - loss: 0.4132 - val_accuracy: 0.8333 - val_auc: 0.9289 - val_loss: 0.3122
# Epoch 54/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - accuracy: 0.7494 - auc: 0.9035 - loss: 0.4083 - val_accuracy: 0.8333 - val_auc: 0.9289 - val_loss: 0.2934
# Epoch 55/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - accuracy: 0.7108 - auc: 0.8846 - loss: 0.4146 - val_accuracy: 0.8333 - val_auc: 0.9156 - val_loss: 0.2958
# Epoch 56/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 204ms/step - accuracy: 0.7277 - auc: 0.8920 - loss: 0.4134 - val_accuracy: 0.8333 - val_auc: 0.9111 - val_loss: 0.2886
# Epoch 57/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.7277 - auc: 0.8944 - loss: 0.4129 - val_accuracy: 0.8333 - val_auc: 0.9133 - val_loss: 0.2850
# Epoch 58/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step - accuracy: 0.7277 - auc: 0.8800 - loss: 0.4126 - val_accuracy: 0.8333 - val_auc: 0.9111 - val_loss: 0.2806
# Epoch 59/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 180ms/step - accuracy: 0.7277 - auc: 0.9012 - loss: 0.3927 - val_accuracy: 0.8333 - val_auc: 0.9111 - val_loss: 0.3044
# Epoch 60/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - accuracy: 0.7277 - auc: 0.9095 - loss: 0.3899 - val_accuracy: 0.8333 - val_auc: 0.9289 - val_loss: 0.2782
# Epoch 61/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 211ms/step - accuracy: 0.7277 - auc: 0.9072 - loss: 0.3949 - val_accuracy: 0.8333 - val_auc: 0.9289 - val_loss: 0.2854
# Epoch 62/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 173ms/step - accuracy: 0.7277 - auc: 0.9002 - loss: 0.4171 - val_accuracy: 0.8333 - val_auc: 0.9200 - val_loss: 0.3025
# Epoch 63/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 191ms/step - accuracy: 0.7277 - auc: 0.9012 - loss: 0.4025 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2955
# Epoch 64/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 186ms/step - accuracy: 0.7164 - auc: 0.8950 - loss: 0.4257 - val_accuracy: 0.8333 - val_auc: 0.9067 - val_loss: 0.3260
# Epoch 65/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - accuracy: 0.7277 - auc: 0.8782 - loss: 0.4479 - val_accuracy: 0.8333 - val_auc: 0.9067 - val_loss: 0.2936
# Epoch 66/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - accuracy: 0.7277 - auc: 0.8554 - loss: 0.4545 - val_accuracy: 0.8333 - val_auc: 0.9200 - val_loss: 0.2841
# Epoch 67/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - accuracy: 0.7277 - auc: 0.8785 - loss: 0.4251 - val_accuracy: 0.8333 - val_auc: 0.9111 - val_loss: 0.2992
# Epoch 68/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 187ms/step - accuracy: 0.7277 - auc: 0.8944 - loss: 0.3998 - val_accuracy: 0.8333 - val_auc: 0.9289 - val_loss: 0.3047
# Epoch 69/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.7277 - auc: 0.8767 - loss: 0.4045 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2758
# Epoch 70/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.7277 - auc: 0.8781 - loss: 0.4082 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2774
# Epoch 71/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 196ms/step - accuracy: 0.7277 - auc: 0.8723 - loss: 0.4203 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2703
# Epoch 72/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step - accuracy: 0.7277 - auc: 0.8929 - loss: 0.4022 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2943
# Epoch 73/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - accuracy: 0.7164 - auc: 0.8858 - loss: 0.3999 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2698
# Epoch 74/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step - accuracy: 0.7277 - auc: 0.9189 - loss: 0.3858 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2854
# Epoch 75/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 177ms/step - accuracy: 0.7277 - auc: 0.9331 - loss: 0.3717 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2723
# Epoch 76/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - accuracy: 0.7277 - auc: 0.9091 - loss: 0.3978 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2696
# Epoch 77/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 190ms/step - accuracy: 0.7164 - auc: 0.8761 - loss: 0.4180 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2685
# Epoch 78/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step - accuracy: 0.7221 - auc: 0.8660 - loss: 0.4196 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2884
# Epoch 79/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.7277 - auc: 0.9085 - loss: 0.3902 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2706
# Epoch 80/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - accuracy: 0.6947 - auc: 0.8761 - loss: 0.3984 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2649
# Epoch 81/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - accuracy: 0.7277 - auc: 0.8191 - loss: 0.4596 - val_accuracy: 0.8333 - val_auc: 0.9444 - val_loss: 0.3194
# Epoch 82/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step - accuracy: 0.7221 - auc: 0.9413 - loss: 0.4362 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2957
# Epoch 83/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 0.7277 - auc: 0.8824 - loss: 0.4208 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2875
# Epoch 84/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - accuracy: 0.7277 - auc: 0.8914 - loss: 0.4137 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2909
# Epoch 85/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.7277 - auc: 0.9006 - loss: 0.4245 - val_accuracy: 0.8333 - val_auc: 0.9289 - val_loss: 0.3185
# Epoch 86/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - accuracy: 0.7277 - auc: 0.8609 - loss: 0.4709 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2757
# Epoch 87/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 194ms/step - accuracy: 0.7277 - auc: 0.9022 - loss: 0.4002 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2683
# Epoch 88/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 194ms/step - accuracy: 0.7619 - auc: 0.9281 - loss: 0.3852 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2816
# Epoch 89/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - accuracy: 0.7390 - auc: 0.9246 - loss: 0.3944 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2995
# Epoch 90/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.7619 - auc: 0.8893 - loss: 0.4266 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2790
# Epoch 91/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - accuracy: 0.7221 - auc: 0.8815 - loss: 0.4099 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2740
# Epoch 92/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 190ms/step - accuracy: 0.7277 - auc: 0.9046 - loss: 0.3671 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2818
# Epoch 93/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - accuracy: 0.7277 - auc: 0.8768 - loss: 0.4306 - val_accuracy: 0.8000 - val_auc: 0.8778 - val_loss: 0.3647
# Epoch 94/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - accuracy: 0.7083 - auc: 0.8003 - loss: 0.4958 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2663
# Epoch 95/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 196ms/step - accuracy: 0.7185 - auc: 0.8812 - loss: 0.4660 - val_accuracy: 0.8000 - val_auc: 0.8911 - val_loss: 0.3221
# Epoch 96/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - accuracy: 0.7277 - auc: 0.8809 - loss: 0.4296 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.3333
# Epoch 97/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 183ms/step - accuracy: 0.7277 - auc: 0.7642 - loss: 0.4863 - val_accuracy: 0.8000 - val_auc: 0.8800 - val_loss: 0.3864
# Epoch 98/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 0.6935 - auc: 0.6749 - loss: 0.5279 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.3356
# Epoch 99/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.7277 - auc: 0.8177 - loss: 0.4729 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.3240
# Epoch 100/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 0.7277 - auc: 0.8844 - loss: 0.4508 - val_accuracy: 0.8333 - val_auc: 0.9178 - val_loss: 0.3139
# Epoch 101/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 178ms/step - accuracy: 0.7277 - auc: 0.8688 - loss: 0.4403 - val_accuracy: 0.8333 - val_auc: 0.9178 - val_loss: 0.3026
# Epoch 102/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 186ms/step - accuracy: 0.7277 - auc: 0.9049 - loss: 0.4183 - val_accuracy: 0.8333 - val_auc: 0.9133 - val_loss: 0.2848
# Epoch 103/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step - accuracy: 0.7277 - auc: 0.8699 - loss: 0.4683 - val_accuracy: 0.8333 - val_auc: 0.9111 - val_loss: 0.2890
# Epoch 104/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - accuracy: 0.7277 - auc: 0.8865 - loss: 0.4355 - val_accuracy: 0.8333 - val_auc: 0.9200 - val_loss: 0.3006
# Epoch 105/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - accuracy: 0.7221 - auc: 0.8849 - loss: 0.4206 - val_accuracy: 0.8333 - val_auc: 0.9111 - val_loss: 0.2848
# Epoch 106/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - accuracy: 0.7277 - auc: 0.8770 - loss: 0.4217 - val_accuracy: 0.8333 - val_auc: 0.9111 - val_loss: 0.2806
# Epoch 107/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 185ms/step - accuracy: 0.7277 - auc: 0.8889 - loss: 0.4174 - val_accuracy: 0.8333 - val_auc: 0.9289 - val_loss: 0.2918
# Epoch 108/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - accuracy: 0.7277 - auc: 0.9304 - loss: 0.4189 - val_accuracy: 0.8333 - val_auc: 0.9133 - val_loss: 0.2706
# Epoch 109/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - accuracy: 0.7277 - auc: 0.9184 - loss: 0.3901 - val_accuracy: 0.8333 - val_auc: 0.9289 - val_loss: 0.2687
# Epoch 110/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 177ms/step - accuracy: 0.7277 - auc: 0.9085 - loss: 0.4024 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2709
# Epoch 111/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - accuracy: 0.7277 - auc: 0.9312 - loss: 0.3872 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2729
# Epoch 112/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 192ms/step - accuracy: 0.7277 - auc: 0.8507 - loss: 0.4212 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.3002
# Epoch 113/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 189ms/step - accuracy: 0.7277 - auc: 0.8759 - loss: 0.4574 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2697
# Epoch 114/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step - accuracy: 0.7277 - auc: 0.9045 - loss: 0.3894 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2679
# Epoch 115/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - accuracy: 0.7277 - auc: 0.8801 - loss: 0.3884 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2601
# Epoch 116/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.7277 - auc: 0.9041 - loss: 0.4137 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2618
# Epoch 117/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - accuracy: 0.7277 - auc: 0.9120 - loss: 0.3877 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2569
# Epoch 118/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - accuracy: 0.7277 - auc: 0.9303 - loss: 0.3705 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2625
# Epoch 119/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - accuracy: 0.7359 - auc: 0.8991 - loss: 0.3958 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2567
# Epoch 120/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 0.7277 - auc: 0.8942 - loss: 0.4265 - val_accuracy: 0.8333 - val_auc: 0.9444 - val_loss: 0.2818
# Epoch 121/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 188ms/step - accuracy: 0.7277 - auc: 0.8529 - loss: 0.4080 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2664
# Epoch 122/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 0.7221 - auc: 0.8988 - loss: 0.4179 - val_accuracy: 0.8333 - val_auc: 0.9444 - val_loss: 0.2834
# Epoch 123/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 0.7108 - auc: 0.8360 - loss: 0.4363 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2531
# Epoch 124/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - accuracy: 0.7619 - auc: 0.9230 - loss: 0.3621 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2527
# Epoch 125/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 0.7060 - auc: 0.8783 - loss: 0.4106 - val_accuracy: 0.8333 - val_auc: 0.9444 - val_loss: 0.2855
# Epoch 126/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - accuracy: 0.7277 - auc: 0.8706 - loss: 0.4234 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2557
# Epoch 127/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.7390 - auc: 0.9165 - loss: 0.3939 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2591
# Epoch 128/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 0.7619 - auc: 0.9367 - loss: 0.3802 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2625
# Epoch 129/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - accuracy: 0.7277 - auc: 0.8925 - loss: 0.4172 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2657
# Epoch 130/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - accuracy: 0.7164 - auc: 0.9082 - loss: 0.3761 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2735
# Epoch 131/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - accuracy: 0.7277 - auc: 0.9112 - loss: 0.3920 - val_accuracy: 0.8000 - val_auc: 0.8911 - val_loss: 0.3225
# Epoch 132/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 184ms/step - accuracy: 0.6807 - auc: 0.8895 - loss: 0.4027 - val_accuracy: 0.8333 - val_auc: 0.9178 - val_loss: 0.2782
# Epoch 133/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 0.7277 - auc: 0.9093 - loss: 0.3672 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2786
# Epoch 134/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - accuracy: 0.7277 - auc: 0.9042 - loss: 0.3806 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2651
# Epoch 135/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 181ms/step - accuracy: 0.7277 - auc: 0.9123 - loss: 0.3482 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2604
# Epoch 136/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 182ms/step - accuracy: 0.7437 - auc: 0.9265 - loss: 0.3627 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2512
# Epoch 137/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - accuracy: 0.7277 - auc: 0.8757 - loss: 0.4001 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2501
# Epoch 138/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 190ms/step - accuracy: 0.7619 - auc: 0.9338 - loss: 0.3584 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2633
# Epoch 139/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - accuracy: 0.7277 - auc: 0.9120 - loss: 0.3742 - val_accuracy: 0.8333 - val_auc: 0.9444 - val_loss: 0.2834
# Epoch 140/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 181ms/step - accuracy: 0.7277 - auc: 0.8960 - loss: 0.4092 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2476
# Epoch 141/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - accuracy: 0.7277 - auc: 0.9029 - loss: 0.3749 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2546
# Epoch 142/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 0.7494 - auc: 0.9254 - loss: 0.3814 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2777
# Epoch 143/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 0.7277 - auc: 0.8832 - loss: 0.4302 - val_accuracy: 0.8333 - val_auc: 0.9444 - val_loss: 0.2808
# Epoch 144/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - accuracy: 0.7277 - auc: 0.8589 - loss: 0.3978 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2534
# Epoch 145/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - accuracy: 0.7277 - auc: 0.8910 - loss: 0.3850 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.3027
# Epoch 146/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - accuracy: 0.7836 - auc: 0.8909 - loss: 0.4297 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2972
# Epoch 147/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 178ms/step - accuracy: 0.7277 - auc: 0.8727 - loss: 0.4066 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2691
# Epoch 148/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - accuracy: 0.7277 - auc: 0.8719 - loss: 0.4556 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2799
# Epoch 149/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 0.7277 - auc: 0.8637 - loss: 0.3976 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2564
# Epoch 150/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - accuracy: 0.7164 - auc: 0.9167 - loss: 0.3867 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2548
# Epoch 151/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - accuracy: 0.7277 - auc: 0.8569 - loss: 0.4651 - val_accuracy: 0.8333 - val_auc: 0.9000 - val_loss: 0.3326
# Epoch 152/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - accuracy: 0.7277 - auc: 0.8115 - loss: 0.4564 - val_accuracy: 0.8333 - val_auc: 0.9111 - val_loss: 0.3245
# Epoch 153/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - accuracy: 0.7277 - auc: 0.8950 - loss: 0.4469 - val_accuracy: 0.8333 - val_auc: 0.9444 - val_loss: 0.2693
# Epoch 154/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - accuracy: 0.7277 - auc: 0.9287 - loss: 0.3756 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2825
# Epoch 155/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.7277 - auc: 0.9049 - loss: 0.4211 - val_accuracy: 0.8333 - val_auc: 0.9444 - val_loss: 0.2812
# Epoch 156/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 0.7277 - auc: 0.8765 - loss: 0.4107 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2656
# Epoch 157/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.7277 - auc: 0.9256 - loss: 0.3753 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2670
# Epoch 158/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 156ms/step - accuracy: 0.7277 - auc: 0.9043 - loss: 0.3935 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2960
# Epoch 159/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.7277 - auc: 0.8840 - loss: 0.4002 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2580
# Epoch 160/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.7277 - auc: 0.9036 - loss: 0.3955 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2688
# Epoch 161/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - accuracy: 0.7060 - auc: 0.8944 - loss: 0.4037 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2663
# Epoch 162/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.7277 - auc: 0.8903 - loss: 0.3806 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2815
# Epoch 163/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.7060 - auc: 0.8786 - loss: 0.4319 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2675
# Epoch 164/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.7277 - auc: 0.9373 - loss: 0.3648 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2814
# Epoch 165/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 0.7277 - auc: 0.9008 - loss: 0.3888 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2668
# Epoch 166/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - accuracy: 0.7277 - auc: 0.8997 - loss: 0.3746 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2842
# Epoch 167/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.7277 - auc: 0.9208 - loss: 0.3741 - val_accuracy: 0.8333 - val_auc: 0.9444 - val_loss: 0.2747
# Epoch 168/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.7277 - auc: 0.9594 - loss: 0.4025 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2697
# Epoch 169/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - accuracy: 0.7221 - auc: 0.9340 - loss: 0.3694 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2655
# Epoch 170/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.7277 - auc: 0.9046 - loss: 0.4143 - val_accuracy: 0.8333 - val_auc: 0.9444 - val_loss: 0.2733
# Epoch 171/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - accuracy: 0.7277 - auc: 0.9067 - loss: 0.3717 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2586
# Epoch 172/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 0.7277 - auc: 0.9136 - loss: 0.3809 - val_accuracy: 0.8333 - val_auc: 0.9222 - val_loss: 0.2708
# Epoch 173/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.7221 - auc: 0.9356 - loss: 0.3497 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2688
# Epoch 174/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.7494 - auc: 0.9247 - loss: 0.3780 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2554
# Epoch 175/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - accuracy: 0.7619 - auc: 0.9365 - loss: 0.3534 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2584
# Epoch 176/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.7277 - auc: 0.8942 - loss: 0.4213 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2690
# Epoch 177/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - accuracy: 0.7277 - auc: 0.9345 - loss: 0.3635 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2539
# Epoch 178/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.7277 - auc: 0.8941 - loss: 0.4204 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2788
# Epoch 179/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.7241 - auc: 0.8818 - loss: 0.3972 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2607
# Epoch 180/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.7277 - auc: 0.9226 - loss: 0.3623 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2624
# Epoch 181/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.7196 - auc: 0.8922 - loss: 0.4394 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2577
# Epoch 182/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - accuracy: 0.7277 - auc: 0.9170 - loss: 0.3628 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2588
# Epoch 183/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 0.7277 - auc: 0.9452 - loss: 0.3551 - val_accuracy: 0.8333 - val_auc: 0.9289 - val_loss: 0.2839
# Epoch 184/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.7277 - auc: 0.9179 - loss: 0.3951 - val_accuracy: 0.8333 - val_auc: 0.9289 - val_loss: 0.2704
# Epoch 185/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - accuracy: 0.7277 - auc: 0.9025 - loss: 0.3478 - val_accuracy: 0.8333 - val_auc: 0.9289 - val_loss: 0.2828
# Epoch 186/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 156ms/step - accuracy: 0.7277 - auc: 0.9014 - loss: 0.4340 - val_accuracy: 0.8333 - val_auc: 0.9289 - val_loss: 0.2633
# Epoch 187/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.7221 - auc: 0.9108 - loss: 0.3840 - val_accuracy: 0.8333 - val_auc: 0.9200 - val_loss: 0.2654
# Epoch 188/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.7277 - auc: 0.9157 - loss: 0.3719 - val_accuracy: 0.8333 - val_auc: 0.9289 - val_loss: 0.2825
# Epoch 189/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.7277 - auc: 0.9068 - loss: 0.3736 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2781
# Epoch 190/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 156ms/step - accuracy: 0.7277 - auc: 0.8843 - loss: 0.3964 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2784
# Epoch 191/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.7277 - auc: 0.8289 - loss: 0.4123 - val_accuracy: 0.8333 - val_auc: 0.9289 - val_loss: 0.2622
# Epoch 192/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - accuracy: 0.7277 - auc: 0.9030 - loss: 0.3600 - val_accuracy: 0.8333 - val_auc: 0.9289 - val_loss: 0.2984
# Epoch 193/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.7164 - auc: 0.9057 - loss: 0.4307 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2687
# Epoch 194/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.7277 - auc: 0.8777 - loss: 0.3914 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2658
# Epoch 195/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - accuracy: 0.7060 - auc: 0.9206 - loss: 0.3525 - val_accuracy: 0.8333 - val_auc: 0.9289 - val_loss: 0.2655
# Epoch 196/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 156ms/step - accuracy: 0.7277 - auc: 0.9215 - loss: 0.3597 - val_accuracy: 0.8333 - val_auc: 0.9289 - val_loss: 0.2607
# Epoch 197/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.7221 - auc: 0.9063 - loss: 0.3608 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2702
# Epoch 198/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - accuracy: 0.7277 - auc: 0.9009 - loss: 0.3960 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2534
# Epoch 199/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.7619 - auc: 0.9315 - loss: 0.3549 - val_accuracy: 0.8333 - val_auc: 0.9333 - val_loss: 0.2709
# Epoch 200/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - accuracy: 0.7277 - auc: 0.9438 - loss: 0.3495 - val_accuracy: 0.8333 - val_auc: 0.9444 - val_loss: 0.2651
# 1it [04:23, 263.15s/it]
# CPU times: user 7min 53s, sys: 2min 48s, total: 10min 41s
# Wall time: 4min 23s

# %%
for i in range(NUM_EPOCHS):
    print(f"Epoch {(i + 1)}: TRAIN Accuracy = {np.round(epoch_acc[i], 3)} Loss = {np.round(epoch_loss[i], 3)} AUC = {np.round(epoch_auc[i], 3)}")
    print(f"Epoch {(i + 1)}: VAL Accuracy = {np.round(epoch_val_acc[i], 3)} Loss = {np.round(epoch_val_loss[i], 3)} AUC = {np.round(epoch_val_auc[i], 3)}")
# Out:
# Epoch 1: TRAIN Accuracy = 0.614 Loss = 0.668 AUC = 0.756
# Epoch 1: VAL Accuracy = 0.767 Loss = 0.632 AUC = 0.789
# Epoch 2: TRAIN Accuracy = 0.757 Loss = 0.613 AUC = 0.783
# Epoch 2: VAL Accuracy = 0.767 Loss = 0.573 AUC = 0.789
# Epoch 3: TRAIN Accuracy = 0.771 Loss = 0.57 AUC = 0.794
# Epoch 3: VAL Accuracy = 0.767 Loss = 0.524 AUC = 0.778
# Epoch 4: TRAIN Accuracy = 0.771 Loss = 0.506 AUC = 0.813
# Epoch 4: VAL Accuracy = 0.767 Loss = 0.487 AUC = 0.778
# Epoch 5: TRAIN Accuracy = 0.771 Loss = 0.496 AUC = 0.774
# Epoch 5: VAL Accuracy = 0.767 Loss = 0.459 AUC = 0.778
# Epoch 6: TRAIN Accuracy = 0.8 Loss = 0.45 AUC = 0.812
# Epoch 6: VAL Accuracy = 0.767 Loss = 0.43 AUC = 0.8
# Epoch 7: TRAIN Accuracy = 0.786 Loss = 0.441 AUC = 0.862
# Epoch 7: VAL Accuracy = 0.833 Loss = 0.415 AUC = 0.8
# Epoch 8: TRAIN Accuracy = 0.8 Loss = 0.429 AUC = 0.84
# Epoch 8: VAL Accuracy = 0.833 Loss = 0.407 AUC = 0.811
# Epoch 9: TRAIN Accuracy = 0.8 Loss = 0.42 AUC = 0.841
# Epoch 9: VAL Accuracy = 0.833 Loss = 0.4 AUC = 0.844
# Epoch 10: TRAIN Accuracy = 0.771 Loss = 0.468 AUC = 0.706
# Epoch 10: VAL Accuracy = 0.833 Loss = 0.393 AUC = 0.844
# Epoch 11: TRAIN Accuracy = 0.8 Loss = 0.449 AUC = 0.747
# Epoch 11: VAL Accuracy = 0.833 Loss = 0.392 AUC = 0.844
# Epoch 12: TRAIN Accuracy = 0.8 Loss = 0.446 AUC = 0.752
# Epoch 12: VAL Accuracy = 0.833 Loss = 0.393 AUC = 0.844
# Epoch 13: TRAIN Accuracy = 0.8 Loss = 0.441 AUC = 0.783
# Epoch 13: VAL Accuracy = 0.833 Loss = 0.392 AUC = 0.856
# Epoch 14: TRAIN Accuracy = 0.8 Loss = 0.427 AUC = 0.825
# Epoch 14: VAL Accuracy = 0.833 Loss = 0.389 AUC = 0.867
# Epoch 15: TRAIN Accuracy = 0.786 Loss = 0.44 AUC = 0.794
# Epoch 15: VAL Accuracy = 0.833 Loss = 0.384 AUC = 0.878
# Epoch 16: TRAIN Accuracy = 0.786 Loss = 0.435 AUC = 0.827
# Epoch 16: VAL Accuracy = 0.833 Loss = 0.383 AUC = 0.889
# Epoch 17: TRAIN Accuracy = 0.8 Loss = 0.421 AUC = 0.852
# Epoch 17: VAL Accuracy = 0.833 Loss = 0.378 AUC = 0.878
# Epoch 18: TRAIN Accuracy = 0.8 Loss = 0.415 AUC = 0.829
# Epoch 18: VAL Accuracy = 0.833 Loss = 0.376 AUC = 0.867
# Epoch 19: TRAIN Accuracy = 0.8 Loss = 0.459 AUC = 0.709
# Epoch 19: VAL Accuracy = 0.833 Loss = 0.374 AUC = 0.889
# Epoch 20: TRAIN Accuracy = 0.8 Loss = 0.43 AUC = 0.781
# Epoch 20: VAL Accuracy = 0.833 Loss = 0.372 AUC = 0.889
# Epoch 21: TRAIN Accuracy = 0.8 Loss = 0.425 AUC = 0.791
# Epoch 21: VAL Accuracy = 0.833 Loss = 0.37 AUC = 0.889
# Epoch 22: TRAIN Accuracy = 0.8 Loss = 0.424 AUC = 0.802
# Epoch 22: VAL Accuracy = 0.833 Loss = 0.368 AUC = 0.922
# Epoch 23: TRAIN Accuracy = 0.8 Loss = 0.407 AUC = 0.864
# Epoch 23: VAL Accuracy = 0.833 Loss = 0.365 AUC = 0.944
# Epoch 24: TRAIN Accuracy = 0.8 Loss = 0.406 AUC = 0.863
# Epoch 24: VAL Accuracy = 0.833 Loss = 0.36 AUC = 0.918
# Epoch 25: TRAIN Accuracy = 0.8 Loss = 0.396 AUC = 0.873
# Epoch 25: VAL Accuracy = 0.833 Loss = 0.356 AUC = 0.92
# Epoch 26: TRAIN Accuracy = 0.8 Loss = 0.425 AUC = 0.797
# Epoch 26: VAL Accuracy = 0.833 Loss = 0.351 AUC = 0.916
# Epoch 27: TRAIN Accuracy = 0.8 Loss = 0.396 AUC = 0.873
# Epoch 27: VAL Accuracy = 0.833 Loss = 0.345 AUC = 0.913
# Epoch 28: TRAIN Accuracy = 0.8 Loss = 0.401 AUC = 0.865
# Epoch 28: VAL Accuracy = 0.833 Loss = 0.34 AUC = 0.92
# Epoch 29: TRAIN Accuracy = 0.8 Loss = 0.401 AUC = 0.863
# Epoch 29: VAL Accuracy = 0.833 Loss = 0.342 AUC = 0.913
# Epoch 30: TRAIN Accuracy = 0.786 Loss = 0.398 AUC = 0.859
# Epoch 30: VAL Accuracy = 0.833 Loss = 0.335 AUC = 0.913
# Epoch 31: TRAIN Accuracy = 0.786 Loss = 0.395 AUC = 0.878
# Epoch 31: VAL Accuracy = 0.833 Loss = 0.33 AUC = 0.929
# Epoch 32: TRAIN Accuracy = 0.8 Loss = 0.388 AUC = 0.884
# Epoch 32: VAL Accuracy = 0.833 Loss = 0.324 AUC = 0.907
# Epoch 33: TRAIN Accuracy = 0.8 Loss = 0.37 AUC = 0.899
# Epoch 33: VAL Accuracy = 0.833 Loss = 0.324 AUC = 0.909
# Epoch 34: TRAIN Accuracy = 0.8 Loss = 0.377 AUC = 0.882
# Epoch 34: VAL Accuracy = 0.833 Loss = 0.317 AUC = 0.916
# Epoch 35: TRAIN Accuracy = 0.8 Loss = 0.384 AUC = 0.866
# Epoch 35: VAL Accuracy = 0.833 Loss = 0.313 AUC = 0.916
# Epoch 36: TRAIN Accuracy = 0.8 Loss = 0.395 AUC = 0.863
# Epoch 36: VAL Accuracy = 0.833 Loss = 0.324 AUC = 0.907
# Epoch 37: TRAIN Accuracy = 0.8 Loss = 0.363 AUC = 0.895
# Epoch 37: VAL Accuracy = 0.833 Loss = 0.328 AUC = 0.911
# Epoch 38: TRAIN Accuracy = 0.8 Loss = 0.369 AUC = 0.885
# Epoch 38: VAL Accuracy = 0.833 Loss = 0.314 AUC = 0.913
# Epoch 39: TRAIN Accuracy = 0.8 Loss = 0.386 AUC = 0.863
# Epoch 39: VAL Accuracy = 0.833 Loss = 0.309 AUC = 0.913
# Epoch 40: TRAIN Accuracy = 0.8 Loss = 0.375 AUC = 0.88
# Epoch 40: VAL Accuracy = 0.833 Loss = 0.313 AUC = 0.907
# Epoch 41: TRAIN Accuracy = 0.8 Loss = 0.365 AUC = 0.898
# Epoch 41: VAL Accuracy = 0.833 Loss = 0.312 AUC = 0.907
# Epoch 42: TRAIN Accuracy = 0.8 Loss = 0.358 AUC = 0.9
# Epoch 42: VAL Accuracy = 0.833 Loss = 0.31 AUC = 0.907
# Epoch 43: TRAIN Accuracy = 0.814 Loss = 0.366 AUC = 0.888
# Epoch 43: VAL Accuracy = 0.833 Loss = 0.317 AUC = 0.907
# Epoch 44: TRAIN Accuracy = 0.8 Loss = 0.369 AUC = 0.887
# Epoch 44: VAL Accuracy = 0.833 Loss = 0.305 AUC = 0.907
# Epoch 45: TRAIN Accuracy = 0.814 Loss = 0.38 AUC = 0.873
# Epoch 45: VAL Accuracy = 0.833 Loss = 0.307 AUC = 0.907
# Epoch 46: TRAIN Accuracy = 0.8 Loss = 0.357 AUC = 0.908
# Epoch 46: VAL Accuracy = 0.833 Loss = 0.309 AUC = 0.907
# Epoch 47: TRAIN Accuracy = 0.814 Loss = 0.369 AUC = 0.876
# Epoch 47: VAL Accuracy = 0.833 Loss = 0.304 AUC = 0.907
# Epoch 48: TRAIN Accuracy = 0.8 Loss = 0.377 AUC = 0.872
# Epoch 48: VAL Accuracy = 0.833 Loss = 0.311 AUC = 0.913
# Epoch 49: TRAIN Accuracy = 0.8 Loss = 0.365 AUC = 0.88
# Epoch 49: VAL Accuracy = 0.833 Loss = 0.305 AUC = 0.911
# Epoch 50: TRAIN Accuracy = 0.8 Loss = 0.379 AUC = 0.887
# Epoch 50: VAL Accuracy = 0.833 Loss = 0.297 AUC = 0.929
# Epoch 51: TRAIN Accuracy = 0.8 Loss = 0.386 AUC = 0.859
# Epoch 51: VAL Accuracy = 0.833 Loss = 0.313 AUC = 0.911
# Epoch 52: TRAIN Accuracy = 0.814 Loss = 0.369 AUC = 0.881
# Epoch 52: VAL Accuracy = 0.833 Loss = 0.301 AUC = 0.922
# Epoch 53: TRAIN Accuracy = 0.757 Loss = 0.37 AUC = 0.882
# Epoch 53: VAL Accuracy = 0.833 Loss = 0.312 AUC = 0.929
# Epoch 54: TRAIN Accuracy = 0.814 Loss = 0.35 AUC = 0.909
# Epoch 54: VAL Accuracy = 0.833 Loss = 0.293 AUC = 0.929
# Epoch 55: TRAIN Accuracy = 0.771 Loss = 0.385 AUC = 0.872
# Epoch 55: VAL Accuracy = 0.833 Loss = 0.296 AUC = 0.916
# Epoch 56: TRAIN Accuracy = 0.8 Loss = 0.372 AUC = 0.867
# Epoch 56: VAL Accuracy = 0.833 Loss = 0.289 AUC = 0.911
# Epoch 57: TRAIN Accuracy = 0.8 Loss = 0.356 AUC = 0.899
# Epoch 57: VAL Accuracy = 0.833 Loss = 0.285 AUC = 0.913
# Epoch 58: TRAIN Accuracy = 0.8 Loss = 0.376 AUC = 0.876
# Epoch 58: VAL Accuracy = 0.833 Loss = 0.281 AUC = 0.911
# Epoch 59: TRAIN Accuracy = 0.8 Loss = 0.343 AUC = 0.891
# Epoch 59: VAL Accuracy = 0.833 Loss = 0.304 AUC = 0.911
# Epoch 60: TRAIN Accuracy = 0.8 Loss = 0.364 AUC = 0.883
# Epoch 60: VAL Accuracy = 0.833 Loss = 0.278 AUC = 0.929
# Epoch 61: TRAIN Accuracy = 0.8 Loss = 0.335 AUC = 0.918
# Epoch 61: VAL Accuracy = 0.833 Loss = 0.285 AUC = 0.929
# Epoch 62: TRAIN Accuracy = 0.8 Loss = 0.402 AUC = 0.867
# Epoch 62: VAL Accuracy = 0.833 Loss = 0.302 AUC = 0.92
# Epoch 63: TRAIN Accuracy = 0.8 Loss = 0.355 AUC = 0.897
# Epoch 63: VAL Accuracy = 0.833 Loss = 0.295 AUC = 0.922
# Epoch 64: TRAIN Accuracy = 0.786 Loss = 0.382 AUC = 0.896
# Epoch 64: VAL Accuracy = 0.833 Loss = 0.326 AUC = 0.907
# Epoch 65: TRAIN Accuracy = 0.8 Loss = 0.384 AUC = 0.885
# Epoch 65: VAL Accuracy = 0.833 Loss = 0.294 AUC = 0.907
# Epoch 66: TRAIN Accuracy = 0.8 Loss = 0.38 AUC = 0.879
# Epoch 66: VAL Accuracy = 0.833 Loss = 0.284 AUC = 0.92
# Epoch 67: TRAIN Accuracy = 0.8 Loss = 0.362 AUC = 0.886
# Epoch 67: VAL Accuracy = 0.833 Loss = 0.299 AUC = 0.911
# Epoch 68: TRAIN Accuracy = 0.8 Loss = 0.352 AUC = 0.89
# Epoch 68: VAL Accuracy = 0.833 Loss = 0.305 AUC = 0.929
# Epoch 69: TRAIN Accuracy = 0.8 Loss = 0.35 AUC = 0.881
# Epoch 69: VAL Accuracy = 0.833 Loss = 0.276 AUC = 0.922
# Epoch 70: TRAIN Accuracy = 0.8 Loss = 0.36 AUC = 0.876
# Epoch 70: VAL Accuracy = 0.833 Loss = 0.277 AUC = 0.922
# Epoch 71: TRAIN Accuracy = 0.8 Loss = 0.367 AUC = 0.898
# Epoch 71: VAL Accuracy = 0.833 Loss = 0.27 AUC = 0.922
# Epoch 72: TRAIN Accuracy = 0.8 Loss = 0.373 AUC = 0.883
# Epoch 72: VAL Accuracy = 0.833 Loss = 0.294 AUC = 0.922
# Epoch 73: TRAIN Accuracy = 0.786 Loss = 0.347 AUC = 0.889
# Epoch 73: VAL Accuracy = 0.833 Loss = 0.27 AUC = 0.922
# Epoch 74: TRAIN Accuracy = 0.8 Loss = 0.363 AUC = 0.891
# Epoch 74: VAL Accuracy = 0.833 Loss = 0.285 AUC = 0.922
# Epoch 75: TRAIN Accuracy = 0.8 Loss = 0.332 AUC = 0.922
# Epoch 75: VAL Accuracy = 0.833 Loss = 0.272 AUC = 0.922
# Epoch 76: TRAIN Accuracy = 0.8 Loss = 0.35 AUC = 0.9
# Epoch 76: VAL Accuracy = 0.833 Loss = 0.27 AUC = 0.922
# Epoch 77: TRAIN Accuracy = 0.771 Loss = 0.365 AUC = 0.894
# Epoch 77: VAL Accuracy = 0.833 Loss = 0.268 AUC = 0.922
# Epoch 78: TRAIN Accuracy = 0.786 Loss = 0.368 AUC = 0.875
# Epoch 78: VAL Accuracy = 0.833 Loss = 0.288 AUC = 0.922
# Epoch 79: TRAIN Accuracy = 0.8 Loss = 0.347 AUC = 0.9
# Epoch 79: VAL Accuracy = 0.833 Loss = 0.271 AUC = 0.922
# Epoch 80: TRAIN Accuracy = 0.771 Loss = 0.359 AUC = 0.885
# Epoch 80: VAL Accuracy = 0.833 Loss = 0.265 AUC = 0.922
# Epoch 81: TRAIN Accuracy = 0.8 Loss = 0.396 AUC = 0.851
# Epoch 81: VAL Accuracy = 0.833 Loss = 0.319 AUC = 0.944
# Epoch 82: TRAIN Accuracy = 0.786 Loss = 0.383 AUC = 0.914
# Epoch 82: VAL Accuracy = 0.833 Loss = 0.296 AUC = 0.922
# Epoch 83: TRAIN Accuracy = 0.8 Loss = 0.364 AUC = 0.884
# Epoch 83: VAL Accuracy = 0.833 Loss = 0.287 AUC = 0.922
# Epoch 84: TRAIN Accuracy = 0.8 Loss = 0.353 AUC = 0.881
# Epoch 84: VAL Accuracy = 0.833 Loss = 0.291 AUC = 0.922
# Epoch 85: TRAIN Accuracy = 0.8 Loss = 0.375 AUC = 0.889
# Epoch 85: VAL Accuracy = 0.833 Loss = 0.319 AUC = 0.929
# Epoch 86: TRAIN Accuracy = 0.8 Loss = 0.396 AUC = 0.875
# Epoch 86: VAL Accuracy = 0.833 Loss = 0.276 AUC = 0.922
# Epoch 87: TRAIN Accuracy = 0.8 Loss = 0.343 AUC = 0.906
# Epoch 87: VAL Accuracy = 0.833 Loss = 0.268 AUC = 0.922
# Epoch 88: TRAIN Accuracy = 0.814 Loss = 0.339 AUC = 0.901
# Epoch 88: VAL Accuracy = 0.833 Loss = 0.282 AUC = 0.922
# Epoch 89: TRAIN Accuracy = 0.814 Loss = 0.343 AUC = 0.917
# Epoch 89: VAL Accuracy = 0.833 Loss = 0.299 AUC = 0.922
# Epoch 90: TRAIN Accuracy = 0.814 Loss = 0.373 AUC = 0.889
# Epoch 90: VAL Accuracy = 0.833 Loss = 0.279 AUC = 0.922
# Epoch 91: TRAIN Accuracy = 0.786 Loss = 0.366 AUC = 0.872
# Epoch 91: VAL Accuracy = 0.833 Loss = 0.274 AUC = 0.922
# Epoch 92: TRAIN Accuracy = 0.8 Loss = 0.322 AUC = 0.896
# Epoch 92: VAL Accuracy = 0.833 Loss = 0.282 AUC = 0.922
# Epoch 93: TRAIN Accuracy = 0.8 Loss = 0.368 AUC = 0.876
# Epoch 93: VAL Accuracy = 0.8 Loss = 0.365 AUC = 0.878
# Epoch 94: TRAIN Accuracy = 0.771 Loss = 0.453 AUC = 0.816
# Epoch 94: VAL Accuracy = 0.833 Loss = 0.266 AUC = 0.922
# Epoch 95: TRAIN Accuracy = 0.771 Loss = 0.504 AUC = 0.865
# Epoch 95: VAL Accuracy = 0.8 Loss = 0.322 AUC = 0.891
# Epoch 96: TRAIN Accuracy = 0.8 Loss = 0.377 AUC = 0.907
# Epoch 96: VAL Accuracy = 0.833 Loss = 0.333 AUC = 0.933
# Epoch 97: TRAIN Accuracy = 0.8 Loss = 0.421 AUC = 0.824
# Epoch 97: VAL Accuracy = 0.8 Loss = 0.386 AUC = 0.88
# Epoch 98: TRAIN Accuracy = 0.786 Loss = 0.428 AUC = 0.805
# Epoch 98: VAL Accuracy = 0.833 Loss = 0.336 AUC = 0.933
# Epoch 99: TRAIN Accuracy = 0.8 Loss = 0.41 AUC = 0.836
# Epoch 99: VAL Accuracy = 0.833 Loss = 0.324 AUC = 0.922
# Epoch 100: TRAIN Accuracy = 0.8 Loss = 0.384 AUC = 0.899
# Epoch 100: VAL Accuracy = 0.833 Loss = 0.314 AUC = 0.918
# Epoch 101: TRAIN Accuracy = 0.8 Loss = 0.382 AUC = 0.867
# Epoch 101: VAL Accuracy = 0.833 Loss = 0.303 AUC = 0.918
# Epoch 102: TRAIN Accuracy = 0.8 Loss = 0.36 AUC = 0.897
# Epoch 102: VAL Accuracy = 0.833 Loss = 0.285 AUC = 0.913
# Epoch 103: TRAIN Accuracy = 0.8 Loss = 0.373 AUC = 0.886
# Epoch 103: VAL Accuracy = 0.833 Loss = 0.289 AUC = 0.911
# Epoch 104: TRAIN Accuracy = 0.8 Loss = 0.368 AUC = 0.875
# Epoch 104: VAL Accuracy = 0.833 Loss = 0.301 AUC = 0.92
# Epoch 105: TRAIN Accuracy = 0.786 Loss = 0.368 AUC = 0.867
# Epoch 105: VAL Accuracy = 0.833 Loss = 0.285 AUC = 0.911
# Epoch 106: TRAIN Accuracy = 0.8 Loss = 0.364 AUC = 0.891
# Epoch 106: VAL Accuracy = 0.833 Loss = 0.281 AUC = 0.911
# Epoch 107: TRAIN Accuracy = 0.8 Loss = 0.353 AUC = 0.886
# Epoch 107: VAL Accuracy = 0.833 Loss = 0.292 AUC = 0.929
# Epoch 108: TRAIN Accuracy = 0.8 Loss = 0.348 AUC = 0.918
# Epoch 108: VAL Accuracy = 0.833 Loss = 0.271 AUC = 0.913
# Epoch 109: TRAIN Accuracy = 0.8 Loss = 0.362 AUC = 0.888
# Epoch 109: VAL Accuracy = 0.833 Loss = 0.269 AUC = 0.929
# Epoch 110: TRAIN Accuracy = 0.8 Loss = 0.339 AUC = 0.906
# Epoch 110: VAL Accuracy = 0.833 Loss = 0.271 AUC = 0.922
# Epoch 111: TRAIN Accuracy = 0.8 Loss = 0.346 AUC = 0.904
# Epoch 111: VAL Accuracy = 0.833 Loss = 0.273 AUC = 0.922
# Epoch 112: TRAIN Accuracy = 0.8 Loss = 0.371 AUC = 0.87
# Epoch 112: VAL Accuracy = 0.833 Loss = 0.3 AUC = 0.922
# Epoch 113: TRAIN Accuracy = 0.8 Loss = 0.365 AUC = 0.904
# Epoch 113: VAL Accuracy = 0.833 Loss = 0.27 AUC = 0.922
# Epoch 114: TRAIN Accuracy = 0.8 Loss = 0.347 AUC = 0.896
# Epoch 114: VAL Accuracy = 0.833 Loss = 0.268 AUC = 0.922
# Epoch 115: TRAIN Accuracy = 0.8 Loss = 0.348 AUC = 0.896
# Epoch 115: VAL Accuracy = 0.833 Loss = 0.26 AUC = 0.922
# Epoch 116: TRAIN Accuracy = 0.8 Loss = 0.349 AUC = 0.905
# Epoch 116: VAL Accuracy = 0.833 Loss = 0.262 AUC = 0.922
# Epoch 117: TRAIN Accuracy = 0.8 Loss = 0.327 AUC = 0.909
# Epoch 117: VAL Accuracy = 0.833 Loss = 0.257 AUC = 0.922
# Epoch 118: TRAIN Accuracy = 0.8 Loss = 0.323 AUC = 0.921
# Epoch 118: VAL Accuracy = 0.833 Loss = 0.263 AUC = 0.922
# Epoch 119: TRAIN Accuracy = 0.814 Loss = 0.352 AUC = 0.901
# Epoch 119: VAL Accuracy = 0.833 Loss = 0.257 AUC = 0.922
# Epoch 120: TRAIN Accuracy = 0.8 Loss = 0.353 AUC = 0.918
# Epoch 120: VAL Accuracy = 0.833 Loss = 0.282 AUC = 0.944
# Epoch 121: TRAIN Accuracy = 0.8 Loss = 0.354 AUC = 0.876
# Epoch 121: VAL Accuracy = 0.833 Loss = 0.266 AUC = 0.922
# Epoch 122: TRAIN Accuracy = 0.786 Loss = 0.35 AUC = 0.898
# Epoch 122: VAL Accuracy = 0.833 Loss = 0.283 AUC = 0.944
# Epoch 123: TRAIN Accuracy = 0.771 Loss = 0.374 AUC = 0.862
# Epoch 123: VAL Accuracy = 0.833 Loss = 0.253 AUC = 0.922
# Epoch 124: TRAIN Accuracy = 0.814 Loss = 0.345 AUC = 0.902
# Epoch 124: VAL Accuracy = 0.833 Loss = 0.253 AUC = 0.922
# Epoch 125: TRAIN Accuracy = 0.786 Loss = 0.364 AUC = 0.894
# Epoch 125: VAL Accuracy = 0.833 Loss = 0.286 AUC = 0.944
# Epoch 126: TRAIN Accuracy = 0.8 Loss = 0.359 AUC = 0.896
# Epoch 126: VAL Accuracy = 0.833 Loss = 0.256 AUC = 0.922
# Epoch 127: TRAIN Accuracy = 0.814 Loss = 0.348 AUC = 0.909
# Epoch 127: VAL Accuracy = 0.833 Loss = 0.259 AUC = 0.933
# Epoch 128: TRAIN Accuracy = 0.814 Loss = 0.335 AUC = 0.941
# Epoch 128: VAL Accuracy = 0.833 Loss = 0.262 AUC = 0.922
# Epoch 129: TRAIN Accuracy = 0.8 Loss = 0.359 AUC = 0.902
# Epoch 129: VAL Accuracy = 0.833 Loss = 0.266 AUC = 0.922
# Epoch 130: TRAIN Accuracy = 0.786 Loss = 0.347 AUC = 0.891
# Epoch 130: VAL Accuracy = 0.833 Loss = 0.274 AUC = 0.933
# Epoch 131: TRAIN Accuracy = 0.8 Loss = 0.365 AUC = 0.893
# Epoch 131: VAL Accuracy = 0.8 Loss = 0.323 AUC = 0.891
# Epoch 132: TRAIN Accuracy = 0.757 Loss = 0.34 AUC = 0.893
# Epoch 132: VAL Accuracy = 0.833 Loss = 0.278 AUC = 0.918
# Epoch 133: TRAIN Accuracy = 0.8 Loss = 0.325 AUC = 0.892
# Epoch 133: VAL Accuracy = 0.833 Loss = 0.279 AUC = 0.922
# Epoch 134: TRAIN Accuracy = 0.8 Loss = 0.341 AUC = 0.895
# Epoch 134: VAL Accuracy = 0.833 Loss = 0.265 AUC = 0.922
# Epoch 135: TRAIN Accuracy = 0.8 Loss = 0.317 AUC = 0.891
# Epoch 135: VAL Accuracy = 0.833 Loss = 0.26 AUC = 0.922
# Epoch 136: TRAIN Accuracy = 0.8 Loss = 0.324 AUC = 0.911
# Epoch 136: VAL Accuracy = 0.833 Loss = 0.251 AUC = 0.933
# Epoch 137: TRAIN Accuracy = 0.8 Loss = 0.338 AUC = 0.898
# Epoch 137: VAL Accuracy = 0.833 Loss = 0.25 AUC = 0.933
# Epoch 138: TRAIN Accuracy = 0.814 Loss = 0.325 AUC = 0.912
# Epoch 138: VAL Accuracy = 0.833 Loss = 0.263 AUC = 0.922
# Epoch 139: TRAIN Accuracy = 0.8 Loss = 0.334 AUC = 0.903
# Epoch 139: VAL Accuracy = 0.833 Loss = 0.283 AUC = 0.944
# Epoch 140: TRAIN Accuracy = 0.8 Loss = 0.371 AUC = 0.889
# Epoch 140: VAL Accuracy = 0.833 Loss = 0.248 AUC = 0.933
# Epoch 141: TRAIN Accuracy = 0.8 Loss = 0.328 AUC = 0.895
# Epoch 141: VAL Accuracy = 0.833 Loss = 0.255 AUC = 0.933
# Epoch 142: TRAIN Accuracy = 0.814 Loss = 0.361 AUC = 0.9
# Epoch 142: VAL Accuracy = 0.833 Loss = 0.278 AUC = 0.922
# Epoch 143: TRAIN Accuracy = 0.8 Loss = 0.366 AUC = 0.885
# Epoch 143: VAL Accuracy = 0.833 Loss = 0.281 AUC = 0.944
# Epoch 144: TRAIN Accuracy = 0.8 Loss = 0.362 AUC = 0.877
# Epoch 144: VAL Accuracy = 0.833 Loss = 0.253 AUC = 0.933
# Epoch 145: TRAIN Accuracy = 0.8 Loss = 0.357 AUC = 0.856
# Epoch 145: VAL Accuracy = 0.833 Loss = 0.303 AUC = 0.933
# Epoch 146: TRAIN Accuracy = 0.829 Loss = 0.375 AUC = 0.901
# Epoch 146: VAL Accuracy = 0.833 Loss = 0.297 AUC = 0.933
# Epoch 147: TRAIN Accuracy = 0.8 Loss = 0.354 AUC = 0.893
# Epoch 147: VAL Accuracy = 0.833 Loss = 0.269 AUC = 0.922
# Epoch 148: TRAIN Accuracy = 0.8 Loss = 0.372 AUC = 0.873
# Epoch 148: VAL Accuracy = 0.833 Loss = 0.28 AUC = 0.933
# Epoch 149: TRAIN Accuracy = 0.8 Loss = 0.34 AUC = 0.893
# Epoch 149: VAL Accuracy = 0.833 Loss = 0.256 AUC = 0.933
# Epoch 150: TRAIN Accuracy = 0.786 Loss = 0.33 AUC = 0.907
# Epoch 150: VAL Accuracy = 0.833 Loss = 0.255 AUC = 0.933
# Epoch 151: TRAIN Accuracy = 0.8 Loss = 0.39 AUC = 0.871
# Epoch 151: VAL Accuracy = 0.833 Loss = 0.333 AUC = 0.9
# Epoch 152: TRAIN Accuracy = 0.8 Loss = 0.394 AUC = 0.843
# Epoch 152: VAL Accuracy = 0.833 Loss = 0.324 AUC = 0.911
# Epoch 153: TRAIN Accuracy = 0.8 Loss = 0.386 AUC = 0.907
# Epoch 153: VAL Accuracy = 0.833 Loss = 0.269 AUC = 0.944
# Epoch 154: TRAIN Accuracy = 0.8 Loss = 0.347 AUC = 0.914
# Epoch 154: VAL Accuracy = 0.833 Loss = 0.283 AUC = 0.922
# Epoch 155: TRAIN Accuracy = 0.8 Loss = 0.355 AUC = 0.898
# Epoch 155: VAL Accuracy = 0.833 Loss = 0.281 AUC = 0.944
# Epoch 156: TRAIN Accuracy = 0.8 Loss = 0.345 AUC = 0.918
# Epoch 156: VAL Accuracy = 0.833 Loss = 0.266 AUC = 0.933
# Epoch 157: TRAIN Accuracy = 0.8 Loss = 0.345 AUC = 0.905
# Epoch 157: VAL Accuracy = 0.833 Loss = 0.267 AUC = 0.922
# Epoch 158: TRAIN Accuracy = 0.8 Loss = 0.348 AUC = 0.892
# Epoch 158: VAL Accuracy = 0.833 Loss = 0.296 AUC = 0.933
# Epoch 159: TRAIN Accuracy = 0.8 Loss = 0.342 AUC = 0.902
# Epoch 159: VAL Accuracy = 0.833 Loss = 0.258 AUC = 0.933
# Epoch 160: TRAIN Accuracy = 0.8 Loss = 0.358 AUC = 0.893
# Epoch 160: VAL Accuracy = 0.833 Loss = 0.269 AUC = 0.933
# Epoch 161: TRAIN Accuracy = 0.786 Loss = 0.355 AUC = 0.911
# Epoch 161: VAL Accuracy = 0.833 Loss = 0.266 AUC = 0.933
# Epoch 162: TRAIN Accuracy = 0.8 Loss = 0.334 AUC = 0.898
# Epoch 162: VAL Accuracy = 0.833 Loss = 0.281 AUC = 0.922
# Epoch 163: TRAIN Accuracy = 0.786 Loss = 0.346 AUC = 0.896
# Epoch 163: VAL Accuracy = 0.833 Loss = 0.268 AUC = 0.933
# Epoch 164: TRAIN Accuracy = 0.8 Loss = 0.316 AUC = 0.916
# Epoch 164: VAL Accuracy = 0.833 Loss = 0.281 AUC = 0.922
# Epoch 165: TRAIN Accuracy = 0.8 Loss = 0.331 AUC = 0.891
# Epoch 165: VAL Accuracy = 0.833 Loss = 0.267 AUC = 0.933
# Epoch 166: TRAIN Accuracy = 0.8 Loss = 0.326 AUC = 0.911
# Epoch 166: VAL Accuracy = 0.833 Loss = 0.284 AUC = 0.922
# Epoch 167: TRAIN Accuracy = 0.8 Loss = 0.331 AUC = 0.903
# Epoch 167: VAL Accuracy = 0.833 Loss = 0.275 AUC = 0.944
# Epoch 168: TRAIN Accuracy = 0.8 Loss = 0.34 AUC = 0.944
# Epoch 168: VAL Accuracy = 0.833 Loss = 0.27 AUC = 0.933
# Epoch 169: TRAIN Accuracy = 0.786 Loss = 0.321 AUC = 0.92
# Epoch 169: VAL Accuracy = 0.833 Loss = 0.265 AUC = 0.933
# Epoch 170: TRAIN Accuracy = 0.8 Loss = 0.356 AUC = 0.899
# Epoch 170: VAL Accuracy = 0.833 Loss = 0.273 AUC = 0.944
# Epoch 171: TRAIN Accuracy = 0.8 Loss = 0.314 AUC = 0.919
# Epoch 171: VAL Accuracy = 0.833 Loss = 0.259 AUC = 0.933
# Epoch 172: TRAIN Accuracy = 0.8 Loss = 0.315 AUC = 0.918
# Epoch 172: VAL Accuracy = 0.833 Loss = 0.271 AUC = 0.922
# Epoch 173: TRAIN Accuracy = 0.786 Loss = 0.309 AUC = 0.917
# Epoch 173: VAL Accuracy = 0.833 Loss = 0.269 AUC = 0.933
# Epoch 174: TRAIN Accuracy = 0.814 Loss = 0.345 AUC = 0.914
# Epoch 174: VAL Accuracy = 0.833 Loss = 0.255 AUC = 0.933
# Epoch 175: TRAIN Accuracy = 0.814 Loss = 0.318 AUC = 0.919
# Epoch 175: VAL Accuracy = 0.833 Loss = 0.258 AUC = 0.933
# Epoch 176: TRAIN Accuracy = 0.8 Loss = 0.346 AUC = 0.895
# Epoch 176: VAL Accuracy = 0.833 Loss = 0.269 AUC = 0.933
# Epoch 177: TRAIN Accuracy = 0.8 Loss = 0.323 AUC = 0.919
# Epoch 177: VAL Accuracy = 0.833 Loss = 0.254 AUC = 0.933
# Epoch 178: TRAIN Accuracy = 0.8 Loss = 0.36 AUC = 0.896
# Epoch 178: VAL Accuracy = 0.833 Loss = 0.279 AUC = 0.933
# Epoch 179: TRAIN Accuracy = 0.786 Loss = 0.375 AUC = 0.887
# Epoch 179: VAL Accuracy = 0.833 Loss = 0.261 AUC = 0.933
# Epoch 180: TRAIN Accuracy = 0.8 Loss = 0.315 AUC = 0.912
# Epoch 180: VAL Accuracy = 0.833 Loss = 0.262 AUC = 0.933
# Epoch 181: TRAIN Accuracy = 0.786 Loss = 0.365 AUC = 0.896
# Epoch 181: VAL Accuracy = 0.833 Loss = 0.258 AUC = 0.933
# Epoch 182: TRAIN Accuracy = 0.8 Loss = 0.323 AUC = 0.905
# Epoch 182: VAL Accuracy = 0.833 Loss = 0.259 AUC = 0.933
# Epoch 183: TRAIN Accuracy = 0.8 Loss = 0.33 AUC = 0.923
# Epoch 183: VAL Accuracy = 0.833 Loss = 0.284 AUC = 0.929
# Epoch 184: TRAIN Accuracy = 0.8 Loss = 0.317 AUC = 0.918
# Epoch 184: VAL Accuracy = 0.833 Loss = 0.27 AUC = 0.929
# Epoch 185: TRAIN Accuracy = 0.8 Loss = 0.301 AUC = 0.904
# Epoch 185: VAL Accuracy = 0.833 Loss = 0.283 AUC = 0.929
# Epoch 186: TRAIN Accuracy = 0.8 Loss = 0.388 AUC = 0.889
# Epoch 186: VAL Accuracy = 0.833 Loss = 0.263 AUC = 0.929
# Epoch 187: TRAIN Accuracy = 0.786 Loss = 0.344 AUC = 0.902
# Epoch 187: VAL Accuracy = 0.833 Loss = 0.265 AUC = 0.92
# Epoch 188: TRAIN Accuracy = 0.8 Loss = 0.352 AUC = 0.896
# Epoch 188: VAL Accuracy = 0.833 Loss = 0.282 AUC = 0.929
# Epoch 189: TRAIN Accuracy = 0.8 Loss = 0.33 AUC = 0.905
# Epoch 189: VAL Accuracy = 0.833 Loss = 0.278 AUC = 0.933
# Epoch 190: TRAIN Accuracy = 0.8 Loss = 0.353 AUC = 0.908
# Epoch 190: VAL Accuracy = 0.833 Loss = 0.278 AUC = 0.933
# Epoch 191: TRAIN Accuracy = 0.8 Loss = 0.353 AUC = 0.873
# Epoch 191: VAL Accuracy = 0.833 Loss = 0.262 AUC = 0.929
# Epoch 192: TRAIN Accuracy = 0.8 Loss = 0.342 AUC = 0.897
# Epoch 192: VAL Accuracy = 0.833 Loss = 0.298 AUC = 0.929
# Epoch 193: TRAIN Accuracy = 0.786 Loss = 0.35 AUC = 0.9
# Epoch 193: VAL Accuracy = 0.833 Loss = 0.269 AUC = 0.933
# Epoch 194: TRAIN Accuracy = 0.8 Loss = 0.34 AUC = 0.884
# Epoch 194: VAL Accuracy = 0.833 Loss = 0.266 AUC = 0.933
# Epoch 195: TRAIN Accuracy = 0.786 Loss = 0.31 AUC = 0.931
# Epoch 195: VAL Accuracy = 0.833 Loss = 0.265 AUC = 0.929
# Epoch 196: TRAIN Accuracy = 0.8 Loss = 0.35 AUC = 0.905
# Epoch 196: VAL Accuracy = 0.833 Loss = 0.261 AUC = 0.929
# Epoch 197: TRAIN Accuracy = 0.786 Loss = 0.325 AUC = 0.905
# Epoch 197: VAL Accuracy = 0.833 Loss = 0.27 AUC = 0.933
# Epoch 198: TRAIN Accuracy = 0.8 Loss = 0.341 AUC = 0.918
# Epoch 198: VAL Accuracy = 0.833 Loss = 0.253 AUC = 0.933
# Epoch 199: TRAIN Accuracy = 0.814 Loss = 0.34 AUC = 0.911
# Epoch 199: VAL Accuracy = 0.833 Loss = 0.271 AUC = 0.933
# Epoch 200: TRAIN Accuracy = 0.8 Loss = 0.315 AUC = 0.923
# Epoch 200: VAL Accuracy = 0.833 Loss = 0.265 AUC = 0.944

# %%
import numpy as np
import shap
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.lines as mlines

def plot_time_series_with_shap(model, X_train, X_test, y_test, j, feature_names, lags=None):
    X_sample, y_sample = X_test[j], y_test[j]
    background = X_train

    explainer = shap.GradientExplainer(model, background)
    shap_values = explainer.shap_values(np.expand_dims(X_sample, axis=0))[0]
    shap_values = np.squeeze(shap_values)

    num_features = len(feature_names)
    if lags is not None:
        num_features = int(num_features / (1 + len(lags)))
        shap_values = shap_values.reshape(-1, 1 + len(lags), num_features)

        for k, lag in enumerate(lags):
            shap_values[:, k + 1, :] = np.roll(shap_values[:, k + 1, :], shift=lag, axis=0)
            shap_values[:lag, k + 1, :] = 0
        shap_values = np.sum(shap_values, axis=1)

    plt.figure(figsize=(15, 8))
    red_colors = cm.Reds(np.linspace(0.2, 0.9, num_features))  # More color variation in red
    blue_colors = cm.Blues(np.linspace(0.2, 0.9, num_features))  # More color variation in blue
    
    scatter_plots = []
    for i in range(num_features):
        cur_feature_shap_values = shap_values[:, i]
        ts = np.arange(X_sample.shape[0])
        c = [red_colors[i] if el > 0 else blue_colors[i] for el in cur_feature_shap_values]
        s = [250000 * np.abs(el) if 250000 * np.abs(el) > 0.05 else 0.05 for el in cur_feature_shap_values]
        
        plt.scatter(ts, X_sample[:, i], color=c, s=s)
        scatter_plots.append((red_colors[i], blue_colors[i], feature_names[i]))
    
    raw_prediction = model.predict(np.expand_dims(X_sample, axis=0))
    prediction = 'Confused' if raw_prediction > 0.5 else 'Not Confused'
    plt.yscale('log')
    plt.xlabel("Timestep")
    plt.ylabel("Feature Value (Log Scale)")
    
    # Custom legend with both blueish and reddish markers
    legend_handles = [
        mlines.Line2D([0], [0], marker='o', color='w', markerfacecolor=red, markersize=5, label=name)
        for red, blue, name in scatter_plots
    ] + [
        mlines.Line2D([0], [0], marker='o', color='w', markerfacecolor=blue, markersize=5)
        for _, blue, _ in scatter_plots
    ]
    legend_labels = [name for _, _, name in scatter_plots] + ["" for _ in scatter_plots]
    
    plt.legend(handles=legend_handles, labels=legend_labels, loc="upper right", ncol=2, handletextpad=1.5)
    plt.title(f"Sample {j}. True value '{'Confused' if y_sample == 1 else 'Not Confused'}'. Predicted '{prediction}': {np.round(raw_prediction, 2)}%")
    plt.show()

# %%
plot_time_series_with_shap(model, X_train, X_test, y_test, 15, FEATURES)
plot_time_series_with_shap(model, X_train, X_test, y_test, 10, FEATURES)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
