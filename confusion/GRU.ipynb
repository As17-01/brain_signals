# %%
import numpy as np
import pandas as pd
import os
import sys
import random

from pathlib import Path
from sklearn.model_selection import GroupKFold

import tensorflow as tf
from tensorflow.keras.metrics import AUC
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, GRU, Input, BatchNormalization, Dropout
# Out:
# 2025-02-13 01:59:25.127125: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-02-13 01:59:25.132018: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-02-13 01:59:25.141763: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739401165.158333 1004981 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739401165.162306 1004981 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-13 01:59:25.180129: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
NUM_EPOCHS = 200

ID = ["ID"]
IDS = ["SubjectID", "VideoID"]
TARGET = ["predefinedlabel"]

FEATURES = [
    "Raw",
    "Delta",
    "Theta",
    "Alpha1",
    "Alpha2",
    "Beta1",
    "Beta2",
    "Gamma1",
    "Gamma2",
]

# %%
data_dir = Path("/home/aseliverstov/projects/brain_signals/data_confusion")
data = pd.read_csv(data_dir / "EEG_data.csv")

data["ID"] = (len(np.unique(data["VideoID"])) * data["SubjectID"] + data["VideoID"]).astype("int")
data = data[ID + FEATURES + TARGET]

data
# Out:
#        ID    Raw      Delta      Theta    Alpha1    Alpha2    Beta1     Beta2  \
# 0       0  278.0   301963.0    90612.0   33735.0   23991.0  27946.0   45097.0
# 1       0  -50.0    73787.0    28083.0    1439.0    2240.0   2746.0    3687.0
# 2       0  101.0   758353.0   383745.0  201999.0   62107.0  36293.0  130536.0
# 3       0   -5.0  2012240.0   129350.0   61236.0   17084.0  11488.0   62462.0
# 4       0   -8.0  1005145.0   354328.0   37102.0   88881.0  45307.0   99603.0
# ...    ..    ...        ...        ...       ...       ...      ...       ...
# 12806  99  -39.0   127574.0     9951.0     709.0   21732.0   3872.0   39728.0
# 12807  99 -275.0   323061.0   797464.0  153171.0  145805.0  39829.0  571280.0
# 12808  99 -426.0   680989.0   154296.0   40068.0   39122.0  10966.0   26975.0
# 12809  99  -84.0   366269.0    27346.0   11444.0    9932.0   1939.0    3283.0
# 12810  99  -49.0  1164555.0  1184366.0   50014.0  124208.0  10634.0  445383.0
#
#         Gamma1   Gamma2  predefinedlabel
# 0      33228.0   8293.0              0.0
# 1       5293.0   2740.0              0.0
# 2      57243.0  25354.0              0.0
# 3      49960.0  33932.0              0.0
# 4      44790.0  29749.0              0.0
# ...        ...      ...              ...
# 12806   2598.0    960.0              1.0
# 12807  36574.0  10010.0              1.0
# 12808  20427.0   2024.0              1.0
# 12809  12323.0   1764.0              1.0
# 12810  22133.0   4482.0              1.0
#
# [12811 rows x 11 columns]

# %%
def reshape_dataset(data):
    features = []
    target = []
    for cur_id in np.unique(data[ID].to_numpy()):
        cur_id_data = data[data[ID].to_numpy() == cur_id]
        target.append(np.mean(cur_id_data[TARGET].to_numpy()).astype("int"))
        features.append(cur_id_data[FEATURES].to_numpy())

    features = pad_sequences(features)
    return np.array(features), np.array(target)

def pad_sequences(arrays, pad_value=0):
    max_length = max(arr.shape[0] for arr in arrays)
    padded_arrays = [
        np.pad(
            arr,
            ((0, max_length - arr.shape[0]), (0, 0)),
            mode='constant',
            constant_values=pad_value)
            for arr in arrays
        ]
    return np.stack(padded_arrays)

def create_model(train):
    model = Sequential()
    model.add(Input(shape=(train.shape[1], train.shape[2])))

    model.add(GRU(64, return_sequences=True))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))

    model.add(GRU(32, return_sequences=False))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))

    model.add(Dense(16, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=["accuracy", AUC(name="auc")])
    return model

# %%
all_histories_acc = []
all_histories_loss = []
all_histories_auc = []

for seed in [1212, 123343, 74432, 64342, 9665]:
    np.random.seed(seed)
    random.seed(seed)
    tf.random.set_seed(seed)

    group_kfold = GroupKFold(n_splits=5)

    for i, (train_index, test_index) in enumerate(group_kfold.split(data[FEATURES], data[TARGET], data[ID])):
        train = data.iloc[train_index]
        test = data.iloc[test_index]

        X_train, y_train = reshape_dataset(train)
        X_test, y_test = reshape_dataset(test)

        y_train = y_train.reshape(-1, 1)
        y_test = y_test.reshape(-1, 1)

        model = create_model(X_train)
        history = model.fit(
            X_train, y_train,
            validation_data=(X_test, y_test),
            epochs=NUM_EPOCHS,
            batch_size=16,
            verbose=0,
        )

        all_histories_acc.append(history.history['val_accuracy'])
        all_histories_loss.append(history.history['val_loss'])
        all_histories_auc.append(history.history['val_auc'])

avg_val_accuracy = np.mean(all_histories_acc, axis=0)
avg_val_loss = np.mean(all_histories_loss, axis=0)
avg_val_auc = np.mean(all_histories_auc, axis=0)

for epoch in range(NUM_EPOCHS):
    print(f"Epoch {epoch + 1}: Val Accuracy = {np.round(avg_val_accuracy[epoch], 2)} AUC = {np.round(avg_val_auc[epoch], 2)} Loss = {np.round(avg_val_loss[epoch], 2)}")
# Out:
# 2025-02-13 01:59:27.009383: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1: Val Accuracy = 0.53 AUC = 0.56 Loss = 0.69
# Epoch 2: Val Accuracy = 0.53 AUC = 0.59 Loss = 0.68
# Epoch 3: Val Accuracy = 0.54 AUC = 0.6 Loss = 0.68
# Epoch 4: Val Accuracy = 0.55 AUC = 0.62 Loss = 0.68
# Epoch 5: Val Accuracy = 0.57 AUC = 0.62 Loss = 0.67
# Epoch 6: Val Accuracy = 0.57 AUC = 0.64 Loss = 0.67
# Epoch 7: Val Accuracy = 0.57 AUC = 0.65 Loss = 0.66
# Epoch 8: Val Accuracy = 0.59 AUC = 0.67 Loss = 0.66
# Epoch 9: Val Accuracy = 0.61 AUC = 0.67 Loss = 0.65
# Epoch 10: Val Accuracy = 0.64 AUC = 0.67 Loss = 0.65
# Epoch 11: Val Accuracy = 0.65 AUC = 0.68 Loss = 0.64
# Epoch 12: Val Accuracy = 0.66 AUC = 0.7 Loss = 0.64
# Epoch 13: Val Accuracy = 0.68 AUC = 0.72 Loss = 0.63
# Epoch 14: Val Accuracy = 0.69 AUC = 0.72 Loss = 0.63
# Epoch 15: Val Accuracy = 0.7 AUC = 0.73 Loss = 0.62
# Epoch 16: Val Accuracy = 0.71 AUC = 0.74 Loss = 0.62
# Epoch 17: Val Accuracy = 0.71 AUC = 0.74 Loss = 0.61
# Epoch 18: Val Accuracy = 0.73 AUC = 0.75 Loss = 0.61
# Epoch 19: Val Accuracy = 0.73 AUC = 0.74 Loss = 0.61
# Epoch 20: Val Accuracy = 0.73 AUC = 0.76 Loss = 0.6
# Epoch 21: Val Accuracy = 0.73 AUC = 0.77 Loss = 0.6
# Epoch 22: Val Accuracy = 0.73 AUC = 0.77 Loss = 0.59
# Epoch 23: Val Accuracy = 0.74 AUC = 0.78 Loss = 0.59
# Epoch 24: Val Accuracy = 0.73 AUC = 0.78 Loss = 0.58
# Epoch 25: Val Accuracy = 0.75 AUC = 0.79 Loss = 0.58
# Epoch 26: Val Accuracy = 0.75 AUC = 0.79 Loss = 0.57
# Epoch 27: Val Accuracy = 0.76 AUC = 0.78 Loss = 0.57
# Epoch 28: Val Accuracy = 0.77 AUC = 0.79 Loss = 0.57
# Epoch 29: Val Accuracy = 0.77 AUC = 0.8 Loss = 0.56
# Epoch 30: Val Accuracy = 0.77 AUC = 0.79 Loss = 0.56
# Epoch 31: Val Accuracy = 0.79 AUC = 0.79 Loss = 0.55
# Epoch 32: Val Accuracy = 0.79 AUC = 0.79 Loss = 0.55
# Epoch 33: Val Accuracy = 0.79 AUC = 0.8 Loss = 0.55
# Epoch 34: Val Accuracy = 0.79 AUC = 0.79 Loss = 0.55
# Epoch 35: Val Accuracy = 0.79 AUC = 0.79 Loss = 0.54
# Epoch 36: Val Accuracy = 0.79 AUC = 0.78 Loss = 0.54
# Epoch 37: Val Accuracy = 0.79 AUC = 0.8 Loss = 0.54
# Epoch 38: Val Accuracy = 0.79 AUC = 0.79 Loss = 0.54
# Epoch 39: Val Accuracy = 0.79 AUC = 0.79 Loss = 0.54
# Epoch 40: Val Accuracy = 0.79 AUC = 0.78 Loss = 0.53
# Epoch 41: Val Accuracy = 0.79 AUC = 0.79 Loss = 0.53
# Epoch 42: Val Accuracy = 0.79 AUC = 0.78 Loss = 0.53
# Epoch 43: Val Accuracy = 0.79 AUC = 0.79 Loss = 0.53
# Epoch 44: Val Accuracy = 0.79 AUC = 0.79 Loss = 0.53
# Epoch 45: Val Accuracy = 0.79 AUC = 0.79 Loss = 0.53
# Epoch 46: Val Accuracy = 0.79 AUC = 0.78 Loss = 0.52
# Epoch 47: Val Accuracy = 0.79 AUC = 0.79 Loss = 0.52
# Epoch 48: Val Accuracy = 0.79 AUC = 0.78 Loss = 0.52
# Epoch 49: Val Accuracy = 0.79 AUC = 0.78 Loss = 0.52
# Epoch 50: Val Accuracy = 0.79 AUC = 0.78 Loss = 0.52
# Epoch 51: Val Accuracy = 0.79 AUC = 0.78 Loss = 0.52
# Epoch 52: Val Accuracy = 0.79 AUC = 0.77 Loss = 0.52
# Epoch 53: Val Accuracy = 0.79 AUC = 0.77 Loss = 0.52
# Epoch 54: Val Accuracy = 0.79 AUC = 0.78 Loss = 0.52
# Epoch 55: Val Accuracy = 0.79 AUC = 0.78 Loss = 0.52
# Epoch 56: Val Accuracy = 0.79 AUC = 0.77 Loss = 0.52
# Epoch 57: Val Accuracy = 0.79 AUC = 0.78 Loss = 0.52
# Epoch 58: Val Accuracy = 0.79 AUC = 0.78 Loss = 0.52
# Epoch 59: Val Accuracy = 0.79 AUC = 0.78 Loss = 0.52
# Epoch 60: Val Accuracy = 0.79 AUC = 0.78 Loss = 0.51
# Epoch 61: Val Accuracy = 0.79 AUC = 0.78 Loss = 0.51
# Epoch 62: Val Accuracy = 0.79 AUC = 0.77 Loss = 0.51
# Epoch 63: Val Accuracy = 0.79 AUC = 0.78 Loss = 0.51
# Epoch 64: Val Accuracy = 0.79 AUC = 0.78 Loss = 0.51
# Epoch 65: Val Accuracy = 0.79 AUC = 0.78 Loss = 0.51
# Epoch 66: Val Accuracy = 0.79 AUC = 0.79 Loss = 0.51
# Epoch 67: Val Accuracy = 0.79 AUC = 0.78 Loss = 0.51
# Epoch 68: Val Accuracy = 0.79 AUC = 0.79 Loss = 0.51
# Epoch 69: Val Accuracy = 0.8 AUC = 0.79 Loss = 0.51
# Epoch 70: Val Accuracy = 0.8 AUC = 0.78 Loss = 0.51
# Epoch 71: Val Accuracy = 0.8 AUC = 0.79 Loss = 0.51
# Epoch 72: Val Accuracy = 0.8 AUC = 0.78 Loss = 0.51
# Epoch 73: Val Accuracy = 0.8 AUC = 0.78 Loss = 0.51
# Epoch 74: Val Accuracy = 0.8 AUC = 0.78 Loss = 0.51
# Epoch 75: Val Accuracy = 0.8 AUC = 0.78 Loss = 0.5
# Epoch 76: Val Accuracy = 0.8 AUC = 0.78 Loss = 0.5
# Epoch 77: Val Accuracy = 0.8 AUC = 0.78 Loss = 0.5
# Epoch 78: Val Accuracy = 0.8 AUC = 0.78 Loss = 0.5
# Epoch 79: Val Accuracy = 0.8 AUC = 0.78 Loss = 0.5
# Epoch 80: Val Accuracy = 0.8 AUC = 0.79 Loss = 0.5
# Epoch 81: Val Accuracy = 0.8 AUC = 0.78 Loss = 0.5
# Epoch 82: Val Accuracy = 0.8 AUC = 0.79 Loss = 0.5
# Epoch 83: Val Accuracy = 0.81 AUC = 0.78 Loss = 0.5
# Epoch 84: Val Accuracy = 0.81 AUC = 0.78 Loss = 0.5
# Epoch 85: Val Accuracy = 0.81 AUC = 0.78 Loss = 0.5
# Epoch 86: Val Accuracy = 0.81 AUC = 0.78 Loss = 0.5
# Epoch 87: Val Accuracy = 0.81 AUC = 0.78 Loss = 0.5
# Epoch 88: Val Accuracy = 0.81 AUC = 0.78 Loss = 0.5
# Epoch 89: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.5
# Epoch 90: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.5
# Epoch 91: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.5
# Epoch 92: Val Accuracy = 0.81 AUC = 0.78 Loss = 0.5
# Epoch 93: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.49
# Epoch 94: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.49
# Epoch 95: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.49
# Epoch 96: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.49
# Epoch 97: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.49
# Epoch 98: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.49
# Epoch 99: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.49
# Epoch 100: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.49
# Epoch 101: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.49
# Epoch 102: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.49
# Epoch 103: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.49
# Epoch 104: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.49
# Epoch 105: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.49
# Epoch 106: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.49
# Epoch 107: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.49
# Epoch 108: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.49
# Epoch 109: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.48
# Epoch 110: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.48
# Epoch 111: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.48
# Epoch 112: Val Accuracy = 0.81 AUC = 0.8 Loss = 0.48
# Epoch 113: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.48
# Epoch 114: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.48
# Epoch 115: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.48
# Epoch 116: Val Accuracy = 0.81 AUC = 0.79 Loss = 0.48
# Epoch 117: Val Accuracy = 0.81 AUC = 0.8 Loss = 0.48
# Epoch 118: Val Accuracy = 0.81 AUC = 0.8 Loss = 0.48
# Epoch 119: Val Accuracy = 0.81 AUC = 0.8 Loss = 0.48
# Epoch 120: Val Accuracy = 0.81 AUC = 0.8 Loss = 0.48
# Epoch 121: Val Accuracy = 0.81 AUC = 0.8 Loss = 0.48
# Epoch 122: Val Accuracy = 0.81 AUC = 0.8 Loss = 0.48
# Epoch 123: Val Accuracy = 0.81 AUC = 0.8 Loss = 0.48
# Epoch 124: Val Accuracy = 0.81 AUC = 0.8 Loss = 0.48
# Epoch 125: Val Accuracy = 0.81 AUC = 0.8 Loss = 0.48
# Epoch 126: Val Accuracy = 0.81 AUC = 0.8 Loss = 0.48
# Epoch 127: Val Accuracy = 0.81 AUC = 0.8 Loss = 0.48
# Epoch 128: Val Accuracy = 0.81 AUC = 0.8 Loss = 0.47
# Epoch 129: Val Accuracy = 0.81 AUC = 0.8 Loss = 0.47
# Epoch 130: Val Accuracy = 0.81 AUC = 0.8 Loss = 0.47
# Epoch 131: Val Accuracy = 0.81 AUC = 0.8 Loss = 0.47
# Epoch 132: Val Accuracy = 0.81 AUC = 0.8 Loss = 0.47
# Epoch 133: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.47
# Epoch 134: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.47
# Epoch 135: Val Accuracy = 0.81 AUC = 0.8 Loss = 0.47
# Epoch 136: Val Accuracy = 0.81 AUC = 0.8 Loss = 0.47
# Epoch 137: Val Accuracy = 0.81 AUC = 0.8 Loss = 0.47
# Epoch 138: Val Accuracy = 0.81 AUC = 0.8 Loss = 0.47
# Epoch 139: Val Accuracy = 0.81 AUC = 0.8 Loss = 0.47
# Epoch 140: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.47
# Epoch 141: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.47
# Epoch 142: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.47
# Epoch 143: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.47
# Epoch 144: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.47
# Epoch 145: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.47
# Epoch 146: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.47
# Epoch 147: Val Accuracy = 0.81 AUC = 0.8 Loss = 0.47
# Epoch 148: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.47
# Epoch 149: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.47
# Epoch 150: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.47
# Epoch 151: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.47
# Epoch 152: Val Accuracy = 0.81 AUC = 0.8 Loss = 0.47
# Epoch 153: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.47
# Epoch 154: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.47
# Epoch 155: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.47
# Epoch 156: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.47
# Epoch 157: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.47
# Epoch 158: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.47
# Epoch 159: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.47
# Epoch 160: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.47
# Epoch 161: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.46
# Epoch 162: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.47
# Epoch 163: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.46
# Epoch 164: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.46
# Epoch 165: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.46
# Epoch 166: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 167: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 168: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 169: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.46
# Epoch 170: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.46
# Epoch 171: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 172: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 173: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.46
# Epoch 174: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 175: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 176: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.46
# Epoch 177: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.46
# Epoch 178: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 179: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.46
# Epoch 180: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.46
# Epoch 181: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 182: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 183: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 184: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 185: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 186: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 187: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 188: Val Accuracy = 0.81 AUC = 0.81 Loss = 0.46
# Epoch 189: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 190: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 191: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 192: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 193: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 194: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 195: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 196: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 197: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 198: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 199: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
# Epoch 200: Val Accuracy = 0.81 AUC = 0.82 Loss = 0.46
